# %%
import mplhep as hep
hep.style.use("CMS")
import matplotlib.pyplot as plt

# %% [markdown]
# # Top pair production cross section as a function of center of mass energy of proton proton collisions

# %%
xsec = [1.554, 42.66, 109.6, 156.1, 420.1, 504.5, 559.2, 598.7]
xsec_nlo = [1.745, 54.42, 145.2, 207.5, 555 , 680.8, 763, 812.5]
energy = [2, 5, 7, 8, 12, 13, 13.6, 14]

# %%
fig, ax = plt.subplots()
ax.plot(energy, xsec, 'o-', label="LO @ QCD")
ax.plot(energy, xsec_nlo, 'o-', label="NLO @ QCD")
ax.set_xlabel('Enegy [TeV]')
ax.set_ylabel(r'$\sigma(p p \rightarrow t\bar{t})$ [pb]')
ax.set_yscale("log")
ax.set_ylim(5, 8000)
ax.legend(loc="best")
plt.show()
fig.tight_layout()
fig.savefig("ttbar_xsec.png")
fig.savefig("ttbar_xsec.pdf")

# %% [markdown]
# # Top pair production cross section as a function of center of mass energy of proton proton collisions

# %%
xsec = [613.2, 578.6, 547.5, 518.6, 492.1, 465.2]
xsec_err = [0.89, 0.7, 0.64, 0.65, 0.61, 0.59]
xsec_nlo = [829.5, 781.4, 735.3 , 699.8, 650, 624.8]
xsec_nlo_err = [4.9, 4.9, 3.7, 4.3, 3.8, 3.7]
top_mass = [166, 168, 170, 172, 174, 176]


fig, ax = plt.subplots()
ax.errorbar(top_mass, xsec, xerr=0, yerr=xsec_err, fmt='o-', label="LO @ QCD")
ax.errorbar(top_mass, xsec_nlo, xerr=0, yerr=xsec_nlo_err, fmt='o-', label="NLO @ QCD")
ax.set_xlabel('Top quark mass [GeV]')
ax.set_ylabel(r'$\sigma(p p \rightarrow t\bar{t})$ [pb]')
#ax.set_yscale("log")
#ax.set_ylim(5, 8000)
ax.legend(loc="best")
plt.show()
fig.tight_layout()
fig.savefig("ttbar_xsec_mass.png")
fig.savefig("ttbar_xsec_mass.pdf")
